# %%
import pandas as pd
import econtools.metrics as mt
import econtools
import numpy as np

# %%
#On charge les 4 fichiers
df_H_target = pd.read_csv("H_target_final.csv")
df_NH_target = pd.read_csv("NH_target_final.csv")
df_H_acquiror = pd.read_csv("H_acquiror_final.csv")
df_NH_acquiror = pd.read_csv("NH_acquiror_final.csv")

# %%
df_H_target[df_H_target["countrycode"] == "AU"]
# Out:
#    countrycode  closing_date        ebitda  r_d_expenses_operating_revenue  \
# 0           AU          2000  9.570515e+06                            0.00
# 1           AU          2001  1.774625e+08                            7.13
# 2           AU          2002  2.240108e+09                           26.82
# 3           AU          2003  2.149000e+09                          179.04
# 4           AU          2004  3.900685e+09                          399.67
# 5           AU          2005  6.745037e+09                          122.58
# 6           AU          2006  8.032743e+09                          124.44
# 7           AU          2007  9.844145e+09                          120.51
# 8           AU          2008  5.739048e+09                           68.09
# 9           AU          2009  4.334822e+09                           84.07
# 10          AU          2010  7.707214e+09                          122.35
# ...
